# %%
import numpy as np
import torch
import matplotlib.pyplot as plt

# %%
from torchvision import datasets
import torchvision.transforms as transforms

# number of subprocesses to use for data loading
num_workers = 0
# how many samples per batch to load
batch_size = 64

# convert data to torch.FloatTensor
transform = transforms.ToTensor()

# get the training datasets
train_data = datasets.MNIST(root='data', train=True,
                                   download=True, transform=transform)

# prepare data loader
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size,
                                           num_workers=num_workers)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to data/MNIST/raw/train-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting data/MNIST/raw/train-images-idx3-ubyte.gz to data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to data/MNIST/raw/train-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting data/MNIST/raw/train-labels-idx1-ubyte.gz to data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to data/MNIST/raw/t10k-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting data/MNIST/raw/t10k-images-idx3-ubyte.gz to data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting data/MNIST/raw/t10k-labels-idx1-ubyte.gz to data/MNIST/raw
# Processing...
# Done!
# /usr/local/lib/python3.6/dist-packages/torchvision/datasets/mnist.py:469: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)

# %%
# obtain one batch of training images
dataiter = iter(train_loader)
images, labels = dataiter.next()
images = images.numpy()

# get one image from the batch
for i in range(0,10):
  img = np.squeeze(images[i])
  fig = plt.figure(figsize = (2,2)) 
  ax = fig.add_subplot(111)
  ax.imshow(img, cmap='Greys_r',interpolation='nearest')

# %%
import torch.nn as nn
import torch.nn.functional as F

class Discriminator(nn.Module):

    def __init__(self, input_size, hidden_dim, output_size):
        super(Discriminator, self).__init__()
        
        # define hidden linear layers
        self.fc1 = nn.Linear(input_size, hidden_dim*4)
        self.fc2 = nn.Linear(hidden_dim*4, hidden_dim*2)       
        self.fc3 = nn.Linear(hidden_dim*2, hidden_dim)
        
        # final fully-connected layer
        self.fc4 = nn.Linear(hidden_dim, output_size)
        
        # dropout layer  to prevent overfitting by randomly setting the outgonig edge of hidden unit t0o 0
        self.dropout = nn.Dropout(0.5)
        
        # for leaky relu instead of dying slope like relu it has small slope for x<0
    def forward(self, x):
        # flatten image
        x = x.view(-1, 28*28)
        # all hidden layers
        x = F.leaky_relu(self.fc1(x), 0.2) # (input, negative_slope=0.2)
        x = self.dropout(x)
        x = F.leaky_relu(self.fc2(x), 0.2)
        x = self.dropout(x)
        x = F.leaky_relu(self.fc3(x), 0.2)
        x = self.dropout(x)
        # final layer
        out = self.fc4(x)

        return out

# %%
class Generator(nn.Module):

    def __init__(self, input_size, hidden_dim, output_size):
        super(Generator, self).__init__()
        
        # define hidden linear layers
        self.fc1 = nn.Linear(input_size, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim*2)
        self.fc3 = nn.Linear(hidden_dim*2, hidden_dim*4)
        
        # final fully-connected layer
        self.fc4 = nn.Linear(hidden_dim*4, output_size)
        
        # dropout layer 
        self.dropout = nn.Dropout(0.4)

    def forward(self, x):
        # all hidden layers
        x = F.leaky_relu(self.fc1(x), 0.2) # (input, negative_slope=0.2)
        x = self.dropout(x)
        x = F.leaky_relu(self.fc2(x), 0.2)
        x = self.dropout(x)
        x = F.leaky_relu(self.fc3(x), 0.2)
        x = self.dropout(x)
        # final layer with tanh applied
        out = F.tanh(self.fc4(x))

        return out

# %%
# Discriminator hyperparams

# Size of input image to discriminator (28*28)
input_size = 784
# Size of discriminator output (real or fake)
d_output_size = 1
# Size of last hidden layer in the discriminator
d_hidden_size = 32

# Generator hyperparams

# Size of latent vector to give to generator
z_size = 100
# Size of discriminator output (generated image)
g_output_size = 784
# Size of first hidden layer in the generator
g_hidden_size = 32

# %%
# instantiate discriminator and generator
D = Discriminator(input_size, d_hidden_size, d_output_size)
G = Generator(z_size, g_hidden_size, g_output_size)

# check that they are as you expect
print(D)
print()
print(G)
# Out:
# Discriminator(
#   (fc1): Linear(in_features=784, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=32, bias=True)
#   (fc4): Linear(in_features=32, out_features=1, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )
#
# Generator(
#   (fc1): Linear(in_features=100, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=128, bias=True)
#   (fc4): Linear(in_features=128, out_features=784, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )

# %%
# Calculate losses
def real_loss(D_out, smooth=False):
    batch_size = D_out.size(0)
    # label smoothing
    if smooth:
        # smooth, real labels = 0.9
        labels = torch.ones(batch_size)*0.9
    else:
        labels = torch.ones(batch_size) # real labels = 1
        
    # numerically stable loss
    criterion = nn.BCEWithLogitsLoss()
    # calculate loss
    loss = criterion(D_out.squeeze(), labels)
    return loss

def fake_loss(D_out):
    batch_size = D_out.size(0)
    labels = torch.zeros(batch_size) # fake labels = 0
    criterion = nn.BCEWithLogitsLoss() #bianry cross entropy 
    # calculate loss
    loss = criterion(D_out.squeeze(), labels)
    return loss

# %%
import torch.optim as optim

# Optimizers
lr = 0.001

# Create optimizers for the discriminator and generator
d_optimizer = optim.Adam(D.parameters(), lr)
g_optimizer = optim.Adam(G.parameters(), lr)

# %%
import pickle as pkl

# training hyperparams
num_epochs = 100

# keep track of loss and generated, "fake" samples
samples = []
losses = []

print_every = 100

# Get some fixed data for sampling. These are images that are held
# constant throughout training, and allow us to inspect the model's performance
sample_size=16
fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
fixed_z = torch.from_numpy(fixed_z).float()

# train the network
D.train()
G.train()
for epoch in range(num_epochs):
    
    for batch_i, (real_images, _) in enumerate(train_loader):
                
        batch_size = real_images.size(0)
        
        ## Important rescaling step ## 
        real_images = real_images*2 - 1  # rescale input images from [0,1) to [-1, 1)
        
        # ============================================
        #            TRAIN THE DISCRIMINATOR
        # ============================================
        
        d_optimizer.zero_grad() #Sets gradients of all model parameters to zero
        
        # 1. Train with real images

        # Compute the discriminator losses on real images 
        # smooth the real labels
        D_real = D(real_images)
        d_real_loss = real_loss(D_real, smooth=True)
        
        # 2. Train with fake images
        
        # Generate fake images
        z = np.random.uniform(-1, 1, size=(batch_size, z_size))
        z = torch.from_numpy(z).float()
        fake_images = G(z)
        
        # Compute the discriminator losses on fake images        
        D_fake = D(fake_images)
        d_fake_loss = fake_loss(D_fake)
        
        # add up loss and perform backprop
        d_loss = d_real_loss + d_fake_loss
        d_loss.backward() #computes the deriviative of the loss w.r.t parameters
        d_optimizer.step() #cause the optimizer to take a step in the direction of gradient
        
        
        # =========================================
        #            TRAIN THE GENERATOR
        # =========================================
        g_optimizer.zero_grad()
        
        # 1. Train with fake images and flipped labels
        
        # Generate fake images
        z = np.random.uniform(-1, 1, size=(batch_size, z_size))
        z = torch.from_numpy(z).float()
        fake_images = G(z)
        
        # Compute the discriminator losses on fake images 
        # using flipped labels!
        D_fake = D(fake_images)
        g_loss = real_loss(D_fake) # use real loss to flip labels
        
        # perform backprop
        g_loss.backward() #computes the deriviative of the loss w.r.t parameters
        g_optimizer.step() #cause the optimizer to take a step in the direction of gradient

        # Print some loss stats
        if batch_i % print_every == 0:
            # print discriminator and generator loss
            print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                    epoch+1, num_epochs, d_loss.item(), g_loss.item()))

    
    ## AFTER EACH EPOCH##
    # append discriminator loss and generator loss
    losses.append((d_loss.item(), g_loss.item()))
    
    # generate and save sample, fake images
    G.eval() # eval mode for generating samples
    samples_z = G(fixed_z)
    samples.append(samples_z)
    G.train() # back to train mode


# Save training generator samples
with open('train_samples.pkl', 'wb') as f:
    pkl.dump(samples, f) #saving the data to designated pickle file
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1614: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# Epoch [    1/  100] | d_loss: 1.4158 | g_loss: 0.7485
# Epoch [    1/  100] | d_loss: 0.4172 | g_loss: 5.4432
# Epoch [    1/  100] | d_loss: 0.7485 | g_loss: 4.0674
# Epoch [    1/  100] | d_loss: 0.9975 | g_loss: 2.1205
# Epoch [    1/  100] | d_loss: 0.7627 | g_loss: 6.6194
# Epoch [    1/  100] | d_loss: 0.9330 | g_loss: 3.9851
# Epoch [    1/  100] | d_loss: 1.0031 | g_loss: 1.6838
# Epoch [    1/  100] | d_loss: 0.9957 | g_loss: 2.6392
# Epoch [    1/  100] | d_loss: 1.1613 | g_loss: 1.2144
# Epoch [    1/  100] | d_loss: 0.8418 | g_loss: 2.1314
# Epoch [    2/  100] | d_loss: 1.0322 | g_loss: 1.2744
# Epoch [    2/  100] | d_loss: 0.8736 | g_loss: 2.6538
# Epoch [    2/  100] | d_loss: 0.8451 | g_loss: 2.0912
# Epoch [    2/  100] | d_loss: 1.0299 | g_loss: 1.7686
# Epoch [    2/  100] | d_loss: 1.0004 | g_loss: 1.1893
# Epoch [    2/  100] | d_loss: 0.9817 | g_loss: 1.9137
# Epoch [    2/  100] | d_loss: 0.9309 | g_loss: 1.9811
# Epoch [    2/  100] | d_loss: 0.9754 | g_loss: 1.4443
# Epoch [    2/  100] | d_loss: 0.7540 | g_loss: 2.7184
# Epoch [    2/  100] | d_loss: 0.7533 | g_loss: 3.6113
# Epoch [    3/  100] | d_loss: 0.9529 | g_loss: 2.1451
# Epoch [    3/  100] | d_loss: 0.7368 | g_loss: 2.7864
# Epoch [    3/  100] | d_loss: 0.8968 | g_loss: 1.4520
# Epoch [    3/  100] | d_loss: 1.0736 | g_loss: 1.3780
# Epoch [    3/  100] | d_loss: 0.7670 | g_loss: 2.0399
# Epoch [    3/  100] | d_loss: 0.9791 | g_loss: 2.0311
# Epoch [    3/  100] | d_loss: 0.9990 | g_loss: 1.6204
# Epoch [    3/  100] | d_loss: 1.1183 | g_loss: 1.6105
# Epoch [    3/  100] | d_loss: 0.9054 | g_loss: 2.4566
# Epoch [    3/  100] | d_loss: 0.9997 | g_loss: 1.5262
# Epoch [    4/  100] | d_loss: 0.9818 | g_loss: 2.2850
# Epoch [    4/  100] | d_loss: 1.1088 | g_loss: 1.4034
# Epoch [    4/  100] | d_loss: 1.2277 | g_loss: 1.3386
# Epoch [    4/  100] | d_loss: 1.1536 | g_loss: 1.4559
# Epoch [    4/  100] | d_loss: 1.1571 | g_loss: 1.4488
# Epoch [    4/  100] | d_loss: 1.1685 | g_loss: 1.2841
# Epoch [    4/  100] | d_loss: 1.2247 | g_loss: 1.0566
# Epoch [    4/  100] | d_loss: 1.0645 | g_loss: 1.2640
# Epoch [    4/  100] | d_loss: 1.1967 | g_loss: 1.2570
# Epoch [    4/  100] | d_loss: 1.1154 | g_loss: 1.1406
# Epoch [    5/  100] | d_loss: 1.2314 | g_loss: 1.1840
# Epoch [    5/  100] | d_loss: 1.2043 | g_loss: 1.2129
# Epoch [    5/  100] | d_loss: 1.2345 | g_loss: 1.1640
# Epoch [    5/  100] | d_loss: 0.9632 | g_loss: 1.4551
# Epoch [    5/  100] | d_loss: 1.0432 | g_loss: 1.6597
# Epoch [    5/  100] | d_loss: 1.2768 | g_loss: 1.0607
# Epoch [    5/  100] | d_loss: 1.1192 | g_loss: 1.1230
# Epoch [    5/  100] | d_loss: 1.1749 | g_loss: 1.1634
# Epoch [    5/  100] | d_loss: 1.2230 | g_loss: 1.3587
# Epoch [    5/  100] | d_loss: 1.1983 | g_loss: 1.1396
# Epoch [    6/  100] | d_loss: 1.1806 | g_loss: 1.2311
# Epoch [    6/  100] | d_loss: 1.3026 | g_loss: 1.1410
# Epoch [    6/  100] | d_loss: 1.1724 | g_loss: 1.0279
# Epoch [    6/  100] | d_loss: 1.0391 | g_loss: 1.3367
# Epoch [    6/  100] | d_loss: 1.1834 | g_loss: 1.1631
# Epoch [    6/  100] | d_loss: 1.3419 | g_loss: 1.2659
# Epoch [    6/  100] | d_loss: 1.2511 | g_loss: 1.0605
# Epoch [    6/  100] | d_loss: 1.3605 | g_loss: 0.9634
# Epoch [    6/  100] | d_loss: 1.2719 | g_loss: 1.2330
# Epoch [    6/  100] | d_loss: 1.1612 | g_loss: 1.0915
# Epoch [    7/  100] | d_loss: 0.9748 | g_loss: 1.9438
# Epoch [    7/  100] | d_loss: 1.2136 | g_loss: 1.4158
# Epoch [    7/  100] | d_loss: 1.2986 | g_loss: 1.0834
# Epoch [    7/  100] | d_loss: 1.1237 | g_loss: 1.3923
# Epoch [    7/  100] | d_loss: 1.1722 | g_loss: 1.1095
# Epoch [    7/  100] | d_loss: 1.2409 | g_loss: 1.1087
# Epoch [    7/  100] | d_loss: 1.2159 | g_loss: 1.1133
# Epoch [    7/  100] | d_loss: 1.1522 | g_loss: 1.1457
# Epoch [    7/  100] | d_loss: 1.3480 | g_loss: 1.1573
# Epoch [    7/  100] | d_loss: 1.2484 | g_loss: 0.9087
# Epoch [    8/  100] | d_loss: 1.2272 | g_loss: 1.1634
# Epoch [    8/  100] | d_loss: 1.2985 | g_loss: 1.1658
# Epoch [    8/  100] | d_loss: 1.3037 | g_loss: 1.2599
# Epoch [    8/  100] | d_loss: 1.3114 | g_loss: 0.8983
# Epoch [    8/  100] | d_loss: 1.2050 | g_loss: 1.0818
# Epoch [    8/  100] | d_loss: 1.3041 | g_loss: 1.1680
# Epoch [    8/  100] | d_loss: 1.3564 | g_loss: 1.0179
# Epoch [    8/  100] | d_loss: 1.2215 | g_loss: 1.1118
# Epoch [    8/  100] | d_loss: 1.2742 | g_loss: 1.0075
# Epoch [    8/  100] | d_loss: 1.2369 | g_loss: 1.0450
# Epoch [    9/  100] | d_loss: 1.2715 | g_loss: 0.9435
# Epoch [    9/  100] | d_loss: 1.2560 | g_loss: 1.0845
# Epoch [    9/  100] | d_loss: 1.2986 | g_loss: 1.0584
# Epoch [    9/  100] | d_loss: 1.2464 | g_loss: 0.8472
# Epoch [    9/  100] | d_loss: 1.2677 | g_loss: 0.8826
# Epoch [    9/  100] | d_loss: 1.3257 | g_loss: 0.7805
# Epoch [    9/  100] | d_loss: 1.3219 | g_loss: 0.8412
# Epoch [    9/  100] | d_loss: 1.2802 | g_loss: 0.8924
# Epoch [    9/  100] | d_loss: 1.2849 | g_loss: 0.8726
# Epoch [    9/  100] | d_loss: 1.3350 | g_loss: 0.8938
# Epoch [   10/  100] | d_loss: 1.2299 | g_loss: 0.9320
# Epoch [   10/  100] | d_loss: 1.2509 | g_loss: 1.1342
# Epoch [   10/  100] | d_loss: 1.1764 | g_loss: 1.1330
# Epoch [   10/  100] | d_loss: 1.3323 | g_loss: 0.8724
# Epoch [   10/  100] | d_loss: 1.3296 | g_loss: 1.1515
# Epoch [   10/  100] | d_loss: 1.3774 | g_loss: 0.8305
# Epoch [   10/  100] | d_loss: 1.2730 | g_loss: 1.0279
# Epoch [   10/  100] | d_loss: 1.3376 | g_loss: 1.0782
# Epoch [   10/  100] | d_loss: 1.3933 | g_loss: 0.8933
# Epoch [   10/  100] | d_loss: 1.3354 | g_loss: 0.8425
# Epoch [   11/  100] | d_loss: 1.3415 | g_loss: 0.8239
# Epoch [   11/  100] | d_loss: 1.2167 | g_loss: 1.1170
# Epoch [   11/  100] | d_loss: 1.3289 | g_loss: 1.2895
# Epoch [   11/  100] | d_loss: 1.3505 | g_loss: 0.9665
# Epoch [   11/  100] | d_loss: 1.2221 | g_loss: 1.0194
# Epoch [   11/  100] | d_loss: 1.3915 | g_loss: 1.0487
# Epoch [   11/  100] | d_loss: 1.2250 | g_loss: 1.2702
# Epoch [   11/  100] | d_loss: 1.2806 | g_loss: 1.2436
# Epoch [   11/  100] | d_loss: 1.3281 | g_loss: 0.9617
# Epoch [   11/  100] | d_loss: 1.1930 | g_loss: 1.1544
# Epoch [   12/  100] | d_loss: 1.1781 | g_loss: 1.1101
# Epoch [   12/  100] | d_loss: 1.3220 | g_loss: 0.8651
# Epoch [   12/  100] | d_loss: 1.2283 | g_loss: 1.2753
# Epoch [   12/  100] | d_loss: 1.2556 | g_loss: 1.0788
# Epoch [   12/  100] | d_loss: 1.2090 | g_loss: 1.0367
# Epoch [   12/  100] | d_loss: 1.4144 | g_loss: 0.8682
# Epoch [   12/  100] | d_loss: 1.3003 | g_loss: 1.0159
# Epoch [   12/  100] | d_loss: 1.2309 | g_loss: 1.0738
# Epoch [   12/  100] | d_loss: 1.3241 | g_loss: 0.9260
# Epoch [   12/  100] | d_loss: 1.3446 | g_loss: 1.0388
# Epoch [   13/  100] | d_loss: 1.2118 | g_loss: 1.1701
# Epoch [   13/  100] | d_loss: 1.2857 | g_loss: 0.8556
# Epoch [   13/  100] | d_loss: 1.1898 | g_loss: 1.3483
# Epoch [   13/  100] | d_loss: 1.2798 | g_loss: 1.0427
# Epoch [   13/  100] | d_loss: 1.2327 | g_loss: 1.0060
# Epoch [   13/  100] | d_loss: 1.3559 | g_loss: 1.0507
# Epoch [   13/  100] | d_loss: 1.4045 | g_loss: 0.7497
# Epoch [   13/  100] | d_loss: 1.1949 | g_loss: 1.3144
# Epoch [   13/  100] | d_loss: 1.2982 | g_loss: 1.1288
# Epoch [   13/  100] | d_loss: 1.2672 | g_loss: 1.0202
# Epoch [   14/  100] | d_loss: 1.1901 | g_loss: 1.0800
# Epoch [   14/  100] | d_loss: 1.2761 | g_loss: 1.1200
# Epoch [   14/  100] | d_loss: 1.3023 | g_loss: 0.7690
# Epoch [   14/  100] | d_loss: 1.2646 | g_loss: 0.9923
# Epoch [   14/  100] | d_loss: 1.2861 | g_loss: 1.0956
# Epoch [   14/  100] | d_loss: 1.3058 | g_loss: 1.0257
# Epoch [   14/  100] | d_loss: 1.1413 | g_loss: 1.1678
# Epoch [   14/  100] | d_loss: 1.2732 | g_loss: 0.9756
# Epoch [   14/  100] | d_loss: 1.3243 | g_loss: 0.8377
# Epoch [   14/  100] | d_loss: 1.2957 | g_loss: 0.9413
# Epoch [   15/  100] | d_loss: 1.2603 | g_loss: 1.0153
# Epoch [   15/  100] | d_loss: 1.2551 | g_loss: 1.0700
# Epoch [   15/  100] | d_loss: 1.4521 | g_loss: 0.8457
# Epoch [   15/  100] | d_loss: 1.4000 | g_loss: 0.8769
# Epoch [   15/  100] | d_loss: 1.2694 | g_loss: 0.8260
# Epoch [   15/  100] | d_loss: 1.2901 | g_loss: 0.9368
# Epoch [   15/  100] | d_loss: 1.2688 | g_loss: 1.0751
# Epoch [   15/  100] | d_loss: 1.2532 | g_loss: 1.2024
# Epoch [   15/  100] | d_loss: 1.2207 | g_loss: 1.6095
# Epoch [   15/  100] | d_loss: 1.2807 | g_loss: 0.9932
# Epoch [   16/  100] | d_loss: 1.3249 | g_loss: 0.8437
# Epoch [   16/  100] | d_loss: 1.3212 | g_loss: 0.9676
# Epoch [   16/  100] | d_loss: 1.2287 | g_loss: 0.9100
# Epoch [   16/  100] | d_loss: 1.2799 | g_loss: 0.8627
# Epoch [   16/  100] | d_loss: 1.2790 | g_loss: 1.1226
# Epoch [   16/  100] | d_loss: 1.3928 | g_loss: 0.9885
# Epoch [   16/  100] | d_loss: 1.2708 | g_loss: 0.8739
# Epoch [   16/  100] | d_loss: 1.3309 | g_loss: 0.9037
# Epoch [   16/  100] | d_loss: 1.3231 | g_loss: 0.8221
# Epoch [   16/  100] | d_loss: 1.2341 | g_loss: 0.9160
# Epoch [   17/  100] | d_loss: 1.3135 | g_loss: 0.9429
# Epoch [   17/  100] | d_loss: 1.1635 | g_loss: 1.2797
# Epoch [   17/  100] | d_loss: 1.3295 | g_loss: 0.8009
# Epoch [   17/  100] | d_loss: 1.3487 | g_loss: 0.8548
# Epoch [   17/  100] | d_loss: 1.3210 | g_loss: 0.7846
# Epoch [   17/  100] | d_loss: 1.3384 | g_loss: 1.2113
# Epoch [   17/  100] | d_loss: 1.3499 | g_loss: 0.7763
# Epoch [   17/  100] | d_loss: 1.3427 | g_loss: 0.8680
# Epoch [   17/  100] | d_loss: 1.2810 | g_loss: 0.9325
# Epoch [   17/  100] | d_loss: 1.2870 | g_loss: 0.8853
# Epoch [   18/  100] | d_loss: 1.3509 | g_loss: 0.8094
# Epoch [   18/  100] | d_loss: 1.3496 | g_loss: 0.7848
# Epoch [   18/  100] | d_loss: 1.3899 | g_loss: 0.7362
# Epoch [   18/  100] | d_loss: 1.2297 | g_loss: 0.9948
# Epoch [   18/  100] | d_loss: 1.3767 | g_loss: 0.8235
# Epoch [   18/  100] | d_loss: 1.1696 | g_loss: 1.5283
# Epoch [   18/  100] | d_loss: 1.4179 | g_loss: 0.8029
# Epoch [   18/  100] | d_loss: 1.3091 | g_loss: 0.9093
# Epoch [   18/  100] | d_loss: 1.2514 | g_loss: 1.3034
# Epoch [   18/  100] | d_loss: 1.2143 | g_loss: 0.7584
# Epoch [   19/  100] | d_loss: 1.2313 | g_loss: 1.2345
# Epoch [   19/  100] | d_loss: 1.2799 | g_loss: 0.8718
# Epoch [   19/  100] | d_loss: 1.3529 | g_loss: 0.8576
# Epoch [   19/  100] | d_loss: 1.3320 | g_loss: 0.8341
# Epoch [   19/  100] | d_loss: 1.3562 | g_loss: 0.8668
# Epoch [   19/  100] | d_loss: 1.2397 | g_loss: 1.0988
# Epoch [   19/  100] | d_loss: 1.2387 | g_loss: 1.1171
# Epoch [   19/  100] | d_loss: 1.3524 | g_loss: 0.8277
# Epoch [   19/  100] | d_loss: 1.2664 | g_loss: 0.9171
# Epoch [   19/  100] | d_loss: 1.2924 | g_loss: 0.8349
# Epoch [   20/  100] | d_loss: 1.3556 | g_loss: 0.8426
# Epoch [   20/  100] | d_loss: 1.1962 | g_loss: 1.2737
# Epoch [   20/  100] | d_loss: 1.2535 | g_loss: 1.0797
# Epoch [   20/  100] | d_loss: 1.3337 | g_loss: 1.0867
# Epoch [   20/  100] | d_loss: 1.3325 | g_loss: 1.0546
# Epoch [   20/  100] | d_loss: 1.3014 | g_loss: 0.8156
# Epoch [   20/  100] | d_loss: 1.3225 | g_loss: 0.8994
# Epoch [   20/  100] | d_loss: 1.4504 | g_loss: 0.8887
# Epoch [   20/  100] | d_loss: 1.3148 | g_loss: 0.8369
# Epoch [   20/  100] | d_loss: 1.3282 | g_loss: 1.2366
# Epoch [   21/  100] | d_loss: 1.2448 | g_loss: 1.0924
# Epoch [   21/  100] | d_loss: 1.3228 | g_loss: 0.8553
# Epoch [   21/  100] | d_loss: 1.2571 | g_loss: 0.8264
# Epoch [   21/  100] | d_loss: 1.3010 | g_loss: 1.1832
# Epoch [   21/  100] | d_loss: 1.3476 | g_loss: 0.9644
# Epoch [   21/  100] | d_loss: 1.3757 | g_loss: 0.8462
# Epoch [   21/  100] | d_loss: 1.3065 | g_loss: 0.9840
# Epoch [   21/  100] | d_loss: 1.3292 | g_loss: 0.8669
# Epoch [   21/  100] | d_loss: 1.2262 | g_loss: 1.1905
# Epoch [   21/  100] | d_loss: 1.3144 | g_loss: 0.8329
# Epoch [   22/  100] | d_loss: 1.3554 | g_loss: 1.2601
# Epoch [   22/  100] | d_loss: 1.3210 | g_loss: 1.0046
# Epoch [   22/  100] | d_loss: 1.3022 | g_loss: 0.7793
# Epoch [   22/  100] | d_loss: 1.2718 | g_loss: 1.0368
# Epoch [   22/  100] | d_loss: 1.2108 | g_loss: 1.1798
# Epoch [   22/  100] | d_loss: 1.3222 | g_loss: 1.0102
# Epoch [   22/  100] | d_loss: 1.2976 | g_loss: 0.7908
# Epoch [   22/  100] | d_loss: 1.2799 | g_loss: 0.8849
# Epoch [   22/  100] | d_loss: 1.2570 | g_loss: 1.1867
# Epoch [   22/  100] | d_loss: 1.2881 | g_loss: 0.8032
# Epoch [   23/  100] | d_loss: 1.2178 | g_loss: 1.1560
# Epoch [   23/  100] | d_loss: 1.3070 | g_loss: 1.0249
# Epoch [   23/  100] | d_loss: 1.2321 | g_loss: 1.0380
# Epoch [   23/  100] | d_loss: 1.3678 | g_loss: 0.9101
# Epoch [   23/  100] | d_loss: 1.3127 | g_loss: 0.9486
# Epoch [   23/  100] | d_loss: 1.2843 | g_loss: 1.0116
# Epoch [   23/  100] | d_loss: 1.3163 | g_loss: 0.7924
# Epoch [   23/  100] | d_loss: 1.2322 | g_loss: 1.2089
# Epoch [   23/  100] | d_loss: 1.3724 | g_loss: 0.7680
# Epoch [   23/  100] | d_loss: 1.3033 | g_loss: 0.8761
# Epoch [   24/  100] | d_loss: 1.3297 | g_loss: 0.8798
# Epoch [   24/  100] | d_loss: 1.2906 | g_loss: 1.2700
# Epoch [   24/  100] | d_loss: 1.3483 | g_loss: 0.8377
# Epoch [   24/  100] | d_loss: 1.3348 | g_loss: 0.8350
# Epoch [   24/  100] | d_loss: 1.3230 | g_loss: 1.0592
# Epoch [   24/  100] | d_loss: 1.2736 | g_loss: 1.0479
# Epoch [   24/  100] | d_loss: 1.3132 | g_loss: 0.7979
# Epoch [   24/  100] | d_loss: 1.3662 | g_loss: 0.8081
# Epoch [   24/  100] | d_loss: 1.3454 | g_loss: 0.8312
# Epoch [   24/  100] | d_loss: 1.3114 | g_loss: 0.9112
# Epoch [   25/  100] | d_loss: 1.3224 | g_loss: 1.1795
# Epoch [   25/  100] | d_loss: 1.4258 | g_loss: 1.0254
# Epoch [   25/  100] | d_loss: 1.2835 | g_loss: 0.7837
# Epoch [   25/  100] | d_loss: 1.3701 | g_loss: 0.8540
# Epoch [   25/  100] | d_loss: 1.3092 | g_loss: 0.9028
# Epoch [   25/  100] | d_loss: 1.2183 | g_loss: 1.3517
# Epoch [   25/  100] | d_loss: 1.4180 | g_loss: 0.7799
# Epoch [   25/  100] | d_loss: 1.3427 | g_loss: 0.8189
# Epoch [   25/  100] | d_loss: 1.3323 | g_loss: 0.8386
# Epoch [   25/  100] | d_loss: 1.3148 | g_loss: 0.8839
# Epoch [   26/  100] | d_loss: 1.3364 | g_loss: 0.7833
# Epoch [   26/  100] | d_loss: 1.3094 | g_loss: 0.8221
# Epoch [   26/  100] | d_loss: 1.3267 | g_loss: 0.9340
# Epoch [   26/  100] | d_loss: 1.3625 | g_loss: 0.8214
# Epoch [   26/  100] | d_loss: 1.3106 | g_loss: 0.8535
# Epoch [   26/  100] | d_loss: 1.3784 | g_loss: 0.8552
# Epoch [   26/  100] | d_loss: 1.2974 | g_loss: 0.9130
# Epoch [   26/  100] | d_loss: 1.2652 | g_loss: 0.9550
# Epoch [   26/  100] | d_loss: 1.3633 | g_loss: 0.8788
# Epoch [   26/  100] | d_loss: 1.3290 | g_loss: 0.8716
# Epoch [   27/  100] | d_loss: 1.3273 | g_loss: 0.8156
# Epoch [   27/  100] | d_loss: 1.2687 | g_loss: 1.3315
# Epoch [   27/  100] | d_loss: 1.3150 | g_loss: 0.8661
# Epoch [   27/  100] | d_loss: 1.3508 | g_loss: 0.8853
# Epoch [   27/  100] | d_loss: 1.3312 | g_loss: 0.8521
# Epoch [   27/  100] | d_loss: 1.2841 | g_loss: 0.8381
# Epoch [   27/  100] | d_loss: 1.3019 | g_loss: 0.8314
# Epoch [   27/  100] | d_loss: 1.2941 | g_loss: 0.8840
# Epoch [   27/  100] | d_loss: 1.3001 | g_loss: 0.8333
# Epoch [   27/  100] | d_loss: 1.3408 | g_loss: 0.8467
# Epoch [   28/  100] | d_loss: 1.3354 | g_loss: 0.7821
# Epoch [   28/  100] | d_loss: 1.3301 | g_loss: 0.8473
# Epoch [   28/  100] | d_loss: 1.3729 | g_loss: 0.8469
# Epoch [   28/  100] | d_loss: 1.3413 | g_loss: 0.9076
# Epoch [   28/  100] | d_loss: 1.3797 | g_loss: 1.0295
# Epoch [   28/  100] | d_loss: 1.3526 | g_loss: 0.7926
# Epoch [   28/  100] | d_loss: 1.3495 | g_loss: 0.8397
# Epoch [   28/  100] | d_loss: 1.3663 | g_loss: 0.7344
# Epoch [   28/  100] | d_loss: 1.3915 | g_loss: 0.8771
# Epoch [   28/  100] | d_loss: 1.3223 | g_loss: 0.8703
# Epoch [   29/  100] | d_loss: 1.3329 | g_loss: 0.9576
# Epoch [   29/  100] | d_loss: 1.3160 | g_loss: 1.2437
# Epoch [   29/  100] | d_loss: 1.2536 | g_loss: 1.1706
# Epoch [   29/  100] | d_loss: 1.3464 | g_loss: 0.8379
# Epoch [   29/  100] | d_loss: 1.3284 | g_loss: 0.8491
# Epoch [   29/  100] | d_loss: 1.3830 | g_loss: 0.8834
# Epoch [   29/  100] | d_loss: 1.3035 | g_loss: 0.8417
# Epoch [   29/  100] | d_loss: 1.2390 | g_loss: 1.0557
# Epoch [   29/  100] | d_loss: 1.3356 | g_loss: 0.7244
# Epoch [   29/  100] | d_loss: 1.3240 | g_loss: 0.8871
# Epoch [   30/  100] | d_loss: 1.3781 | g_loss: 0.8912
# Epoch [   30/  100] | d_loss: 1.2503 | g_loss: 1.3178
# Epoch [   30/  100] | d_loss: 1.3801 | g_loss: 0.8418
# Epoch [   30/  100] | d_loss: 1.3519 | g_loss: 0.8485
# Epoch [   30/  100] | d_loss: 1.3583 | g_loss: 0.8655
# Epoch [   30/  100] | d_loss: 1.3669 | g_loss: 0.8700
# Epoch [   30/  100] | d_loss: 1.2724 | g_loss: 1.2776
# Epoch [   30/  100] | d_loss: 1.3124 | g_loss: 0.8770
# Epoch [   30/  100] | d_loss: 1.3060 | g_loss: 0.9483
# Epoch [   30/  100] | d_loss: 1.3895 | g_loss: 0.7952
# Epoch [   31/  100] | d_loss: 1.3287 | g_loss: 0.8432
# Epoch [   31/  100] | d_loss: 1.3484 | g_loss: 0.8426
# Epoch [   31/  100] | d_loss: 1.3742 | g_loss: 0.8980
# Epoch [   31/  100] | d_loss: 1.2992 | g_loss: 0.8917
# Epoch [   31/  100] | d_loss: 1.3380 | g_loss: 0.9097
# Epoch [   31/  100] | d_loss: 1.2779 | g_loss: 0.8521
# Epoch [   31/  100] | d_loss: 1.3503 | g_loss: 0.8118
# Epoch [   31/  100] | d_loss: 1.3355 | g_loss: 1.0171
# Epoch [   31/  100] | d_loss: 1.3888 | g_loss: 0.8292
# Epoch [   31/  100] | d_loss: 1.3693 | g_loss: 0.7385
# Epoch [   32/  100] | d_loss: 1.3473 | g_loss: 0.7923
# Epoch [   32/  100] | d_loss: 1.3664 | g_loss: 0.8281
# Epoch [   32/  100] | d_loss: 1.2580 | g_loss: 1.2396
# Epoch [   32/  100] | d_loss: 1.3972 | g_loss: 0.8308
# Epoch [   32/  100] | d_loss: 1.3328 | g_loss: 0.8111
# Epoch [   32/  100] | d_loss: 1.3676 | g_loss: 0.7932
# Epoch [   32/  100] | d_loss: 1.3601 | g_loss: 0.7902
# Epoch [   32/  100] | d_loss: 1.3156 | g_loss: 1.0850
# Epoch [   32/  100] | d_loss: 1.4485 | g_loss: 0.7426
# Epoch [   32/  100] | d_loss: 1.3235 | g_loss: 0.8543
# Epoch [   33/  100] | d_loss: 1.3712 | g_loss: 0.8460
# Epoch [   33/  100] | d_loss: 1.2732 | g_loss: 1.1786
# Epoch [   33/  100] | d_loss: 1.2304 | g_loss: 0.7790
# Epoch [   33/  100] | d_loss: 1.3535 | g_loss: 1.0282
# Epoch [   33/  100] | d_loss: 1.3348 | g_loss: 0.8202
# Epoch [   33/  100] | d_loss: 1.3509 | g_loss: 0.7977
# Epoch [   33/  100] | d_loss: 1.3862 | g_loss: 0.8543
# Epoch [   33/  100] | d_loss: 1.4170 | g_loss: 0.7677
# Epoch [   33/  100] | d_loss: 1.3497 | g_loss: 0.8271
# Epoch [   33/  100] | d_loss: 1.2753 | g_loss: 1.1116
# Epoch [   34/  100] | d_loss: 1.3605 | g_loss: 0.8033
# Epoch [   34/  100] | d_loss: 1.3076 | g_loss: 0.8333
# Epoch [   34/  100] | d_loss: 1.3388 | g_loss: 0.8793
# Epoch [   34/  100] | d_loss: 1.2320 | g_loss: 0.9553
# Epoch [   34/  100] | d_loss: 1.3465 | g_loss: 0.8011
# Epoch [   34/  100] | d_loss: 1.3137 | g_loss: 1.1978
# Epoch [   34/  100] | d_loss: 1.3898 | g_loss: 0.8251
# Epoch [   34/  100] | d_loss: 1.3305 | g_loss: 0.8459
# Epoch [   34/  100] | d_loss: 1.3066 | g_loss: 0.8293
# Epoch [   34/  100] | d_loss: 1.3361 | g_loss: 1.1084
# Epoch [   35/  100] | d_loss: 1.2703 | g_loss: 1.0839
# Epoch [   35/  100] | d_loss: 1.3495 | g_loss: 1.0154
# Epoch [   35/  100] | d_loss: 1.3608 | g_loss: 0.8258
# Epoch [   35/  100] | d_loss: 1.4169 | g_loss: 0.8954
# Epoch [   35/  100] | d_loss: 1.3594 | g_loss: 0.8527
# Epoch [   35/  100] | d_loss: 1.3493 | g_loss: 0.8751
# Epoch [   35/  100] | d_loss: 1.3522 | g_loss: 0.7845
# Epoch [   35/  100] | d_loss: 1.3409 | g_loss: 0.8900
# Epoch [   35/  100] | d_loss: 1.3117 | g_loss: 0.8087
# Epoch [   35/  100] | d_loss: 1.3452 | g_loss: 1.1711
# Epoch [   36/  100] | d_loss: 1.2025 | g_loss: 1.0892
# Epoch [   36/  100] | d_loss: 1.4047 | g_loss: 0.8407
# Epoch [   36/  100] | d_loss: 1.4053 | g_loss: 1.0537
# Epoch [   36/  100] | d_loss: 1.3505 | g_loss: 0.9568
# Epoch [   36/  100] | d_loss: 1.3326 | g_loss: 0.7868
# Epoch [   36/  100] | d_loss: 1.3418 | g_loss: 0.8469
# Epoch [   36/  100] | d_loss: 1.3465 | g_loss: 0.8682
# Epoch [   36/  100] | d_loss: 1.3443 | g_loss: 0.9333
# Epoch [   36/  100] | d_loss: 1.4087 | g_loss: 0.8053
# Epoch [   36/  100] | d_loss: 1.3867 | g_loss: 0.7842
# Epoch [   37/  100] | d_loss: 1.3409 | g_loss: 0.9989
# Epoch [   37/  100] | d_loss: 1.3496 | g_loss: 0.8701
# Epoch [   37/  100] | d_loss: 1.3763 | g_loss: 0.7448
# Epoch [   37/  100] | d_loss: 1.3486 | g_loss: 0.8534
# Epoch [   37/  100] | d_loss: 1.3453 | g_loss: 0.9476
# Epoch [   37/  100] | d_loss: 1.3530 | g_loss: 0.8190
# Epoch [   37/  100] | d_loss: 1.3497 | g_loss: 0.7805
# Epoch [   37/  100] | d_loss: 1.3082 | g_loss: 0.8798
# Epoch [   37/  100] | d_loss: 1.4224 | g_loss: 0.7238
# Epoch [   37/  100] | d_loss: 1.3521 | g_loss: 0.8002
# Epoch [   38/  100] | d_loss: 1.3827 | g_loss: 0.7986
# Epoch [   38/  100] | d_loss: 1.3494 | g_loss: 0.8212
# Epoch [   38/  100] | d_loss: 1.3105 | g_loss: 0.8437
# Epoch [   38/  100] | d_loss: 1.3117 | g_loss: 0.8196
# Epoch [   38/  100] | d_loss: 1.3317 | g_loss: 0.8906
# Epoch [   38/  100] | d_loss: 1.3466 | g_loss: 1.1846
# Epoch [   38/  100] | d_loss: 1.3183 | g_loss: 0.8411
# Epoch [   38/  100] | d_loss: 1.2633 | g_loss: 0.9399
# Epoch [   38/  100] | d_loss: 1.4103 | g_loss: 0.7988
# Epoch [   38/  100] | d_loss: 1.3234 | g_loss: 0.7912
# Epoch [   39/  100] | d_loss: 1.3134 | g_loss: 0.8147
# Epoch [   39/  100] | d_loss: 1.3505 | g_loss: 0.7888
# Epoch [   39/  100] | d_loss: 1.3556 | g_loss: 0.8669
# Epoch [   39/  100] | d_loss: 1.2873 | g_loss: 0.9168
# Epoch [   39/  100] | d_loss: 1.3153 | g_loss: 0.9159
# Epoch [   39/  100] | d_loss: 1.4189 | g_loss: 0.9570
# Epoch [   39/  100] | d_loss: 1.3648 | g_loss: 0.7826
# Epoch [   39/  100] | d_loss: 1.2944 | g_loss: 0.8496
# Epoch [   39/  100] | d_loss: 1.3225 | g_loss: 1.0728
# Epoch [   39/  100] | d_loss: 1.3039 | g_loss: 1.0321
# Epoch [   40/  100] | d_loss: 1.3775 | g_loss: 0.8598
# Epoch [   40/  100] | d_loss: 1.3322 | g_loss: 0.9847
# Epoch [   40/  100] | d_loss: 1.3489 | g_loss: 1.0950
# Epoch [   40/  100] | d_loss: 1.4127 | g_loss: 0.6994
# Epoch [   40/  100] | d_loss: 1.3846 | g_loss: 0.7936
# Epoch [   40/  100] | d_loss: 1.3933 | g_loss: 0.8693
# Epoch [   40/  100] | d_loss: 1.3337 | g_loss: 0.8286
# Epoch [   40/  100] | d_loss: 1.3822 | g_loss: 0.8521
# Epoch [   40/  100] | d_loss: 1.3430 | g_loss: 0.8477
# Epoch [   40/  100] | d_loss: 1.3355 | g_loss: 0.8959
# Epoch [   41/  100] | d_loss: 1.3945 | g_loss: 0.8508
# Epoch [   41/  100] | d_loss: 1.3121 | g_loss: 0.8898
# Epoch [   41/  100] | d_loss: 1.2473 | g_loss: 1.0081
# Epoch [   41/  100] | d_loss: 1.3268 | g_loss: 0.9481
# Epoch [   41/  100] | d_loss: 1.2812 | g_loss: 1.0349
# Epoch [   41/  100] | d_loss: 1.3710 | g_loss: 0.8167
# Epoch [   41/  100] | d_loss: 1.3044 | g_loss: 0.8464
# Epoch [   41/  100] | d_loss: 1.3852 | g_loss: 0.7821
# Epoch [   41/  100] | d_loss: 1.3745 | g_loss: 0.8517
# Epoch [   41/  100] | d_loss: 1.2738 | g_loss: 0.8417
# Epoch [   42/  100] | d_loss: 1.3151 | g_loss: 0.8566
# Epoch [   42/  100] | d_loss: 1.3204 | g_loss: 1.1493
# Epoch [   42/  100] | d_loss: 1.3680 | g_loss: 0.8642
# Epoch [   42/  100] | d_loss: 1.3842 | g_loss: 0.8328
# Epoch [   42/  100] | d_loss: 1.3902 | g_loss: 0.9970
# Epoch [   42/  100] | d_loss: 1.3765 | g_loss: 0.8257
# Epoch [   42/  100] | d_loss: 1.3243 | g_loss: 1.0645
# Epoch [   42/  100] | d_loss: 1.3942 | g_loss: 0.8206
# Epoch [   42/  100] | d_loss: 1.3314 | g_loss: 0.9503
# Epoch [   42/  100] | d_loss: 1.3531 | g_loss: 0.8066
# Epoch [   43/  100] | d_loss: 1.3331 | g_loss: 0.8606
# Epoch [   43/  100] | d_loss: 1.3310 | g_loss: 0.9185
# Epoch [   43/  100] | d_loss: 1.3456 | g_loss: 0.7856
# Epoch [   43/  100] | d_loss: 1.3741 | g_loss: 0.8038
# Epoch [   43/  100] | d_loss: 1.3592 | g_loss: 0.8424
# Epoch [   43/  100] | d_loss: 1.3655 | g_loss: 0.8926
# Epoch [   43/  100] | d_loss: 1.3553 | g_loss: 0.8485
# Epoch [   43/  100] | d_loss: 1.3802 | g_loss: 1.0617
# Epoch [   43/  100] | d_loss: 1.2922 | g_loss: 1.1447
# Epoch [   43/  100] | d_loss: 1.3260 | g_loss: 0.7776
# Epoch [   44/  100] | d_loss: 1.3647 | g_loss: 0.7771
# Epoch [   44/  100] | d_loss: 1.3777 | g_loss: 0.8953
# Epoch [   44/  100] | d_loss: 1.3284 | g_loss: 0.8060
# Epoch [   44/  100] | d_loss: 1.4215 | g_loss: 0.8662
# Epoch [   44/  100] | d_loss: 1.3635 | g_loss: 0.8491
# Epoch [   44/  100] | d_loss: 1.3392 | g_loss: 0.9446
# Epoch [   44/  100] | d_loss: 1.2670 | g_loss: 1.0711
# Epoch [   44/  100] | d_loss: 1.4359 | g_loss: 0.7916
# Epoch [   44/  100] | d_loss: 1.3640 | g_loss: 0.8172
# Epoch [   44/  100] | d_loss: 1.3308 | g_loss: 0.8186
# Epoch [   45/  100] | d_loss: 1.3251 | g_loss: 0.8718
# Epoch [   45/  100] | d_loss: 1.3137 | g_loss: 0.8614
# Epoch [   45/  100] | d_loss: 1.3110 | g_loss: 0.8589
# Epoch [   45/  100] | d_loss: 1.3483 | g_loss: 1.0269
# Epoch [   45/  100] | d_loss: 1.3026 | g_loss: 0.8313
# Epoch [   45/  100] | d_loss: 1.3379 | g_loss: 0.8552
# Epoch [   45/  100] | d_loss: 1.3399 | g_loss: 0.8542
# Epoch [   45/  100] | d_loss: 1.3417 | g_loss: 0.8831
# Epoch [   45/  100] | d_loss: 1.3812 | g_loss: 0.8408
# Epoch [   45/  100] | d_loss: 1.3062 | g_loss: 0.9697
# Epoch [   46/  100] | d_loss: 1.3794 | g_loss: 1.2546
# Epoch [   46/  100] | d_loss: 1.3372 | g_loss: 0.7758
# Epoch [   46/  100] | d_loss: 1.3889 | g_loss: 0.9012
# Epoch [   46/  100] | d_loss: 1.3116 | g_loss: 1.0232
# Epoch [   46/  100] | d_loss: 1.2570 | g_loss: 0.9646
# Epoch [   46/  100] | d_loss: 1.3478 | g_loss: 0.8578
# Epoch [   46/  100] | d_loss: 1.3897 | g_loss: 0.8466
# Epoch [   46/  100] | d_loss: 1.3383 | g_loss: 0.8497
# Epoch [   46/  100] | d_loss: 1.3558 | g_loss: 0.8816
# Epoch [   46/  100] | d_loss: 1.3449 | g_loss: 0.8975
# Epoch [   47/  100] | d_loss: 1.3266 | g_loss: 0.8992
# Epoch [   47/  100] | d_loss: 1.3145 | g_loss: 1.0042
# Epoch [   47/  100] | d_loss: 1.3440 | g_loss: 0.9892
# Epoch [   47/  100] | d_loss: 1.2956 | g_loss: 0.8365
# Epoch [   47/  100] | d_loss: 1.3763 | g_loss: 0.8501
# Epoch [   47/  100] | d_loss: 1.3306 | g_loss: 0.9757
# Epoch [   47/  100] | d_loss: 1.2958 | g_loss: 1.1139
# Epoch [   47/  100] | d_loss: 1.2928 | g_loss: 0.8412
# Epoch [   47/  100] | d_loss: 1.3200 | g_loss: 0.7890
# Epoch [   47/  100] | d_loss: 1.3442 | g_loss: 0.8119
# Epoch [   48/  100] | d_loss: 1.3324 | g_loss: 0.8501
# Epoch [   48/  100] | d_loss: 1.3610 | g_loss: 0.7963
# Epoch [   48/  100] | d_loss: 1.3907 | g_loss: 0.7755
# Epoch [   48/  100] | d_loss: 1.4280 | g_loss: 0.8085
# Epoch [   48/  100] | d_loss: 1.3869 | g_loss: 0.8867
# Epoch [   48/  100] | d_loss: 1.3485 | g_loss: 0.8731
# Epoch [   48/  100] | d_loss: 1.3536 | g_loss: 0.8581
# Epoch [   48/  100] | d_loss: 1.3708 | g_loss: 0.7849
# Epoch [   48/  100] | d_loss: 1.3779 | g_loss: 0.7777
# Epoch [   48/  100] | d_loss: 1.3238 | g_loss: 0.8627
# Epoch [   49/  100] | d_loss: 1.3500 | g_loss: 0.7466
# Epoch [   49/  100] | d_loss: 1.3036 | g_loss: 0.8323
# Epoch [   49/  100] | d_loss: 1.3535 | g_loss: 0.8840
# Epoch [   49/  100] | d_loss: 1.3520 | g_loss: 0.8703
# Epoch [   49/  100] | d_loss: 1.3503 | g_loss: 0.8393
# Epoch [   49/  100] | d_loss: 1.3105 | g_loss: 0.8982
# Epoch [   49/  100] | d_loss: 1.3443 | g_loss: 0.9528
# Epoch [   49/  100] | d_loss: 1.3528 | g_loss: 0.7906
# Epoch [   49/  100] | d_loss: 1.3534 | g_loss: 0.8644
# Epoch [   49/  100] | d_loss: 1.3062 | g_loss: 0.9408
# Epoch [   50/  100] | d_loss: 1.2905 | g_loss: 0.9791
# Epoch [   50/  100] | d_loss: 1.2788 | g_loss: 0.8139
# Epoch [   50/  100] | d_loss: 1.3454 | g_loss: 0.8683
# Epoch [   50/  100] | d_loss: 1.3463 | g_loss: 0.9018
# Epoch [   50/  100] | d_loss: 1.3417 | g_loss: 0.8397
# Epoch [   50/  100] | d_loss: 1.2758 | g_loss: 1.0718
# Epoch [   50/  100] | d_loss: 1.3558 | g_loss: 0.8324
# Epoch [   50/  100] | d_loss: 1.3185 | g_loss: 0.8591
# Epoch [   50/  100] | d_loss: 1.3669 | g_loss: 0.8494
# Epoch [   50/  100] | d_loss: 1.3624 | g_loss: 0.8638
# Epoch [   51/  100] | d_loss: 1.3506 | g_loss: 0.7933
# Epoch [   51/  100] | d_loss: 1.3236 | g_loss: 0.8630
# Epoch [   51/  100] | d_loss: 1.2850 | g_loss: 0.9823
# Epoch [   51/  100] | d_loss: 1.2873 | g_loss: 1.2470
# Epoch [   51/  100] | d_loss: 1.2912 | g_loss: 0.9830
# Epoch [   51/  100] | d_loss: 1.3361 | g_loss: 0.8280
# Epoch [   51/  100] | d_loss: 1.3167 | g_loss: 0.8616
# Epoch [   51/  100] | d_loss: 1.3007 | g_loss: 1.0262
# Epoch [   51/  100] | d_loss: 1.3545 | g_loss: 0.9481
# Epoch [   51/  100] | d_loss: 1.3561 | g_loss: 1.1469
# Epoch [   52/  100] | d_loss: 1.2990 | g_loss: 1.0799
# Epoch [   52/  100] | d_loss: 1.3391 | g_loss: 1.0891
# Epoch [   52/  100] | d_loss: 1.3245 | g_loss: 0.8084
# Epoch [   52/  100] | d_loss: 1.3698 | g_loss: 0.8579
# Epoch [   52/  100] | d_loss: 1.3595 | g_loss: 0.8423
# Epoch [   52/  100] | d_loss: 1.3583 | g_loss: 0.8578
# Epoch [   52/  100] | d_loss: 1.3780 | g_loss: 0.8509
# Epoch [   52/  100] | d_loss: 1.4463 | g_loss: 0.7522
# Epoch [   52/  100] | d_loss: 1.3481 | g_loss: 0.9998
# Epoch [   52/  100] | d_loss: 1.3064 | g_loss: 1.0163
# Epoch [   53/  100] | d_loss: 1.3246 | g_loss: 0.9942
# Epoch [   53/  100] | d_loss: 1.3092 | g_loss: 1.2248
# Epoch [   53/  100] | d_loss: 1.3406 | g_loss: 0.8918
# Epoch [   53/  100] | d_loss: 1.3686 | g_loss: 0.9669
# Epoch [   53/  100] | d_loss: 1.3531 | g_loss: 0.8150
# Epoch [   53/  100] | d_loss: 1.3119 | g_loss: 0.8878
# Epoch [   53/  100] | d_loss: 1.3612 | g_loss: 0.8440
# Epoch [   53/  100] | d_loss: 1.3505 | g_loss: 0.8906
# Epoch [   53/  100] | d_loss: 1.3195 | g_loss: 0.8811
# Epoch [   53/  100] | d_loss: 1.2550 | g_loss: 1.0984
# Epoch [   54/  100] | d_loss: 1.3785 | g_loss: 0.8662
# Epoch [   54/  100] | d_loss: 1.2840 | g_loss: 1.0245
# Epoch [   54/  100] | d_loss: 1.3378 | g_loss: 0.8252
# Epoch [   54/  100] | d_loss: 1.3647 | g_loss: 0.9064
# Epoch [   54/  100] | d_loss: 1.3960 | g_loss: 0.8645
# Epoch [   54/  100] | d_loss: 1.2921 | g_loss: 0.9491
# Epoch [   54/  100] | d_loss: 1.2909 | g_loss: 0.9176
# Epoch [   54/  100] | d_loss: 1.3820 | g_loss: 0.7079
# Epoch [   54/  100] | d_loss: 1.3950 | g_loss: 0.8657
# Epoch [   54/  100] | d_loss: 1.3462 | g_loss: 0.8857
# Epoch [   55/  100] | d_loss: 1.3332 | g_loss: 0.8357
# Epoch [   55/  100] | d_loss: 1.3036 | g_loss: 0.7900
# Epoch [   55/  100] | d_loss: 1.3418 | g_loss: 0.9026
# Epoch [   55/  100] | d_loss: 1.3498 | g_loss: 1.0839
# Epoch [   55/  100] | d_loss: 1.3570 | g_loss: 0.9362
# Epoch [   55/  100] | d_loss: 1.3093 | g_loss: 0.8509
# Epoch [   55/  100] | d_loss: 1.3207 | g_loss: 1.0120
# Epoch [   55/  100] | d_loss: 1.3614 | g_loss: 0.8544
# Epoch [   55/  100] | d_loss: 1.3429 | g_loss: 0.8325
# Epoch [   55/  100] | d_loss: 1.3204 | g_loss: 0.8687
# Epoch [   56/  100] | d_loss: 1.3413 | g_loss: 0.8715
# Epoch [   56/  100] | d_loss: 1.3708 | g_loss: 0.8964
# Epoch [   56/  100] | d_loss: 1.3676 | g_loss: 1.0371
# Epoch [   56/  100] | d_loss: 1.5062 | g_loss: 0.7593
# Epoch [   56/  100] | d_loss: 1.3374 | g_loss: 0.8732
# Epoch [   56/  100] | d_loss: 1.3658 | g_loss: 0.8566
# Epoch [   56/  100] | d_loss: 1.3702 | g_loss: 0.8673
# Epoch [   56/  100] | d_loss: 1.3245 | g_loss: 0.8960
# Epoch [   56/  100] | d_loss: 1.3156 | g_loss: 0.8797
# Epoch [   56/  100] | d_loss: 1.3649 | g_loss: 0.8867
# Epoch [   57/  100] | d_loss: 1.3209 | g_loss: 0.9083
# Epoch [   57/  100] | d_loss: 1.3249 | g_loss: 0.9125
# Epoch [   57/  100] | d_loss: 1.3246 | g_loss: 0.7941
# Epoch [   57/  100] | d_loss: 1.2921 | g_loss: 0.8396
# Epoch [   57/  100] | d_loss: 1.3187 | g_loss: 0.9090
# Epoch [   57/  100] | d_loss: 1.2993 | g_loss: 1.2964
# Epoch [   57/  100] | d_loss: 1.3391 | g_loss: 0.8015
# Epoch [   57/  100] | d_loss: 1.3200 | g_loss: 0.8693
# Epoch [   57/  100] | d_loss: 1.3735 | g_loss: 0.7983
# Epoch [   57/  100] | d_loss: 1.3256 | g_loss: 0.8923
# Epoch [   58/  100] | d_loss: 1.3261 | g_loss: 0.8269
# Epoch [   58/  100] | d_loss: 1.3250 | g_loss: 0.8646
# Epoch [   58/  100] | d_loss: 1.2941 | g_loss: 1.0541
# Epoch [   58/  100] | d_loss: 1.3988 | g_loss: 0.8067
# Epoch [   58/  100] | d_loss: 1.3014 | g_loss: 0.9214
# Epoch [   58/  100] | d_loss: 1.3221 | g_loss: 0.9416
# Epoch [   58/  100] | d_loss: 1.3408 | g_loss: 0.7932
# Epoch [   58/  100] | d_loss: 1.2983 | g_loss: 0.7908
# Epoch [   58/  100] | d_loss: 1.3359 | g_loss: 0.8701
# Epoch [   58/  100] | d_loss: 1.3251 | g_loss: 0.8742
# Epoch [   59/  100] | d_loss: 1.3251 | g_loss: 0.8596
# Epoch [   59/  100] | d_loss: 1.3356 | g_loss: 0.8960
# Epoch [   59/  100] | d_loss: 1.4382 | g_loss: 0.7931
# Epoch [   59/  100] | d_loss: 1.3414 | g_loss: 0.8491
# Epoch [   59/  100] | d_loss: 1.3364 | g_loss: 0.8554
# Epoch [   59/  100] | d_loss: 1.3702 | g_loss: 0.8440
# Epoch [   59/  100] | d_loss: 1.3407 | g_loss: 0.8620
# Epoch [   59/  100] | d_loss: 1.2982 | g_loss: 0.8449
# Epoch [   59/  100] | d_loss: 1.3702 | g_loss: 0.7466
# Epoch [   59/  100] | d_loss: 1.4178 | g_loss: 0.7756
# Epoch [   60/  100] | d_loss: 1.3336 | g_loss: 0.7652
# Epoch [   60/  100] | d_loss: 1.2715 | g_loss: 1.0242
# Epoch [   60/  100] | d_loss: 1.3330 | g_loss: 0.7646
# Epoch [   60/  100] | d_loss: 1.3820 | g_loss: 0.8702
# Epoch [   60/  100] | d_loss: 1.2905 | g_loss: 0.9156
# Epoch [   60/  100] | d_loss: 1.3502 | g_loss: 0.8844
# Epoch [   60/  100] | d_loss: 1.2462 | g_loss: 1.1848
# Epoch [   60/  100] | d_loss: 1.3323 | g_loss: 0.8268
# Epoch [   60/  100] | d_loss: 1.3354 | g_loss: 0.8570
# Epoch [   60/  100] | d_loss: 1.3010 | g_loss: 0.8856
# Epoch [   61/  100] | d_loss: 1.3093 | g_loss: 1.0163
# Epoch [   61/  100] | d_loss: 1.3054 | g_loss: 0.8659
# Epoch [   61/  100] | d_loss: 1.3582 | g_loss: 0.8898
# Epoch [   61/  100] | d_loss: 1.3335 | g_loss: 0.8729
# Epoch [   61/  100] | d_loss: 1.3634 | g_loss: 0.8895
# Epoch [   61/  100] | d_loss: 1.3351 | g_loss: 0.9410
# Epoch [   61/  100] | d_loss: 1.3146 | g_loss: 1.1923
# Epoch [   61/  100] | d_loss: 1.3073 | g_loss: 0.9457
# Epoch [   61/  100] | d_loss: 1.3631 | g_loss: 1.2581
# Epoch [   61/  100] | d_loss: 1.4019 | g_loss: 0.9638
# Epoch [   62/  100] | d_loss: 1.3009 | g_loss: 1.2531
# Epoch [   62/  100] | d_loss: 1.3415 | g_loss: 0.9668
# Epoch [   62/  100] | d_loss: 1.3631 | g_loss: 1.0610
# Epoch [   62/  100] | d_loss: 1.2394 | g_loss: 1.1170
# Epoch [   62/  100] | d_loss: 1.3193 | g_loss: 1.1493
# Epoch [   62/  100] | d_loss: 1.2681 | g_loss: 1.1367
# Epoch [   62/  100] | d_loss: 1.3992 | g_loss: 0.7882
# Epoch [   62/  100] | d_loss: 1.2508 | g_loss: 0.8316
# Epoch [   62/  100] | d_loss: 1.4500 | g_loss: 0.7350
# Epoch [   62/  100] | d_loss: 1.3532 | g_loss: 0.8606
# Epoch [   63/  100] | d_loss: 1.3655 | g_loss: 1.1097
# Epoch [   63/  100] | d_loss: 1.2867 | g_loss: 0.9157
# Epoch [   63/  100] | d_loss: 1.3618 | g_loss: 0.9787
# Epoch [   63/  100] | d_loss: 1.4536 | g_loss: 0.8275
# Epoch [   63/  100] | d_loss: 1.3372 | g_loss: 0.8941
# Epoch [   63/  100] | d_loss: 1.3285 | g_loss: 0.8259
# Epoch [   63/  100] | d_loss: 1.3218 | g_loss: 0.8718
# Epoch [   63/  100] | d_loss: 1.2082 | g_loss: 0.8751
# Epoch [   63/  100] | d_loss: 1.2328 | g_loss: 1.1516
# Epoch [   63/  100] | d_loss: 1.2623 | g_loss: 1.0074
# Epoch [   64/  100] | d_loss: 1.3036 | g_loss: 0.9949
# Epoch [   64/  100] | d_loss: 1.2943 | g_loss: 1.0562
# Epoch [   64/  100] | d_loss: 1.3975 | g_loss: 1.0226
# Epoch [   64/  100] | d_loss: 1.3288 | g_loss: 0.8682
# Epoch [   64/  100] | d_loss: 1.3984 | g_loss: 0.9221
# Epoch [   64/  100] | d_loss: 1.3064 | g_loss: 0.8732
# Epoch [   64/  100] | d_loss: 1.3716 | g_loss: 0.8526
# Epoch [   64/  100] | d_loss: 1.3104 | g_loss: 0.8798
# Epoch [   64/  100] | d_loss: 1.3508 | g_loss: 0.8215
# Epoch [   64/  100] | d_loss: 1.3113 | g_loss: 0.9382
# Epoch [   65/  100] | d_loss: 1.3073 | g_loss: 0.9819
# Epoch [   65/  100] | d_loss: 1.3459 | g_loss: 0.8545
# Epoch [   65/  100] | d_loss: 1.3361 | g_loss: 0.8764
# Epoch [   65/  100] | d_loss: 1.3387 | g_loss: 0.8736
# Epoch [   65/  100] | d_loss: 1.2906 | g_loss: 0.7989
# Epoch [   65/  100] | d_loss: 1.2951 | g_loss: 0.9771
# Epoch [   65/  100] | d_loss: 1.3465 | g_loss: 0.8569
# Epoch [   65/  100] | d_loss: 1.3669 | g_loss: 0.8359
# Epoch [   65/  100] | d_loss: 1.3750 | g_loss: 0.7785
# Epoch [   65/  100] | d_loss: 1.3468 | g_loss: 0.8789
# Epoch [   66/  100] | d_loss: 1.3209 | g_loss: 0.8157
# Epoch [   66/  100] | d_loss: 1.3097 | g_loss: 0.8792
# Epoch [   66/  100] | d_loss: 1.3068 | g_loss: 0.8596
# Epoch [   66/  100] | d_loss: 1.3456 | g_loss: 1.0468
# Epoch [   66/  100] | d_loss: 1.3284 | g_loss: 0.9165
# Epoch [   66/  100] | d_loss: 1.3570 | g_loss: 0.8072
# Epoch [   66/  100] | d_loss: 1.3751 | g_loss: 0.8176
# Epoch [   66/  100] | d_loss: 1.3460 | g_loss: 0.9193
# Epoch [   66/  100] | d_loss: 1.3187 | g_loss: 0.9167
# Epoch [   66/  100] | d_loss: 1.3403 | g_loss: 0.8893
# Epoch [   67/  100] | d_loss: 1.4016 | g_loss: 0.9299
# Epoch [   67/  100] | d_loss: 1.3470 | g_loss: 0.8605
# Epoch [   67/  100] | d_loss: 1.3454 | g_loss: 0.8803
# Epoch [   67/  100] | d_loss: 1.3162 | g_loss: 0.9722
# Epoch [   67/  100] | d_loss: 1.3456 | g_loss: 0.8500
# Epoch [   67/  100] | d_loss: 1.3380 | g_loss: 0.8450
# Epoch [   67/  100] | d_loss: 1.3369 | g_loss: 0.8530
# Epoch [   67/  100] | d_loss: 1.3597 | g_loss: 0.8695
# Epoch [   67/  100] | d_loss: 1.2692 | g_loss: 1.0588
# Epoch [   67/  100] | d_loss: 1.3051 | g_loss: 1.1666
# Epoch [   68/  100] | d_loss: 1.2842 | g_loss: 0.9709
# Epoch [   68/  100] | d_loss: 1.3489 | g_loss: 0.9276
# Epoch [   68/  100] | d_loss: 1.3815 | g_loss: 0.8305
# Epoch [   68/  100] | d_loss: 1.3531 | g_loss: 0.8823
# Epoch [   68/  100] | d_loss: 1.3454 | g_loss: 0.8705
# Epoch [   68/  100] | d_loss: 1.3509 | g_loss: 0.8349
# Epoch [   68/  100] | d_loss: 1.3319 | g_loss: 0.8110
# Epoch [   68/  100] | d_loss: 1.3038 | g_loss: 0.9061
# Epoch [   68/  100] | d_loss: 1.3554 | g_loss: 0.8694
# Epoch [   68/  100] | d_loss: 1.3600 | g_loss: 0.9811
# Epoch [   69/  100] | d_loss: 1.3575 | g_loss: 0.8644
# Epoch [   69/  100] | d_loss: 1.3261 | g_loss: 0.8787
# Epoch [   69/  100] | d_loss: 1.3363 | g_loss: 0.7923
# Epoch [   69/  100] | d_loss: 1.3730 | g_loss: 0.8612
# Epoch [   69/  100] | d_loss: 1.2655 | g_loss: 1.1874
# Epoch [   69/  100] | d_loss: 1.4202 | g_loss: 0.9971
# Epoch [   69/  100] | d_loss: 1.3612 | g_loss: 0.9148
# Epoch [   69/  100] | d_loss: 1.3297 | g_loss: 0.8720
# Epoch [   69/  100] | d_loss: 1.3581 | g_loss: 0.8897
# Epoch [   69/  100] | d_loss: 1.3450 | g_loss: 1.0071
# Epoch [   70/  100] | d_loss: 1.3477 | g_loss: 0.8805
# Epoch [   70/  100] | d_loss: 1.2801 | g_loss: 0.9312
# Epoch [   70/  100] | d_loss: 1.3369 | g_loss: 0.7898
# Epoch [   70/  100] | d_loss: 1.3377 | g_loss: 0.8834
# Epoch [   70/  100] | d_loss: 1.3003 | g_loss: 0.8651
# Epoch [   70/  100] | d_loss: 1.3487 | g_loss: 0.8518
# Epoch [   70/  100] | d_loss: 1.2654 | g_loss: 0.8227
# Epoch [   70/  100] | d_loss: 1.3525 | g_loss: 0.9445
# Epoch [   70/  100] | d_loss: 1.3497 | g_loss: 0.8331
# Epoch [   70/  100] | d_loss: 1.3264 | g_loss: 0.8928
# Epoch [   71/  100] | d_loss: 1.4018 | g_loss: 0.8097
# Epoch [   71/  100] | d_loss: 1.3436 | g_loss: 0.9245
# Epoch [   71/  100] | d_loss: 1.3784 | g_loss: 0.7783
# Epoch [   71/  100] | d_loss: 1.3658 | g_loss: 0.9031
# Epoch [   71/  100] | d_loss: 1.4732 | g_loss: 0.9267
# Epoch [   71/  100] | d_loss: 1.3977 | g_loss: 0.8345
# Epoch [   71/  100] | d_loss: 1.3018 | g_loss: 0.8680
# Epoch [   71/  100] | d_loss: 1.3780 | g_loss: 0.7963
# Epoch [   71/  100] | d_loss: 1.3725 | g_loss: 0.8546
# Epoch [   71/  100] | d_loss: 1.3597 | g_loss: 0.8518
# Epoch [   72/  100] | d_loss: 1.4024 | g_loss: 0.9015
# Epoch [   72/  100] | d_loss: 1.3246 | g_loss: 0.8464
# Epoch [   72/  100] | d_loss: 1.3321 | g_loss: 0.8339
# Epoch [   72/  100] | d_loss: 1.3783 | g_loss: 0.8584
# Epoch [   72/  100] | d_loss: 1.2491 | g_loss: 0.8301
# Epoch [   72/  100] | d_loss: 1.3238 | g_loss: 0.9146
# Epoch [   72/  100] | d_loss: 1.3216 | g_loss: 0.8446
# Epoch [   72/  100] | d_loss: 1.3751 | g_loss: 0.8820
# Epoch [   72/  100] | d_loss: 1.3109 | g_loss: 0.8277
# Epoch [   72/  100] | d_loss: 1.2629 | g_loss: 0.8678
# Epoch [   73/  100] | d_loss: 1.3361 | g_loss: 0.7950
# Epoch [   73/  100] | d_loss: 1.3851 | g_loss: 0.8474
# Epoch [   73/  100] | d_loss: 1.3864 | g_loss: 0.8673
# Epoch [   73/  100] | d_loss: 1.3947 | g_loss: 0.8840
# Epoch [   73/  100] | d_loss: 1.3611 | g_loss: 0.8659
# Epoch [   73/  100] | d_loss: 1.3722 | g_loss: 0.8421
# Epoch [   73/  100] | d_loss: 1.3299 | g_loss: 0.8558
# Epoch [   73/  100] | d_loss: 1.3221 | g_loss: 0.7933
# Epoch [   73/  100] | d_loss: 1.3231 | g_loss: 0.8371
# Epoch [   73/  100] | d_loss: 1.2968 | g_loss: 0.8429
# Epoch [   74/  100] | d_loss: 1.3782 | g_loss: 0.9018
# Epoch [   74/  100] | d_loss: 1.3353 | g_loss: 1.2041
# Epoch [   74/  100] | d_loss: 1.3657 | g_loss: 0.8299
# Epoch [   74/  100] | d_loss: 1.3894 | g_loss: 0.8058
# Epoch [   74/  100] | d_loss: 1.3280 | g_loss: 0.8268
# Epoch [   74/  100] | d_loss: 1.3355 | g_loss: 0.9117
# Epoch [   74/  100] | d_loss: 1.2816 | g_loss: 0.8596
# Epoch [   74/  100] | d_loss: 1.2777 | g_loss: 0.8501
# Epoch [   74/  100] | d_loss: 1.3162 | g_loss: 1.1101
# Epoch [   74/  100] | d_loss: 1.3174 | g_loss: 0.8737
# Epoch [   75/  100] | d_loss: 1.3105 | g_loss: 0.8883
# Epoch [   75/  100] | d_loss: 1.3147 | g_loss: 0.8697
# Epoch [   75/  100] | d_loss: 1.3004 | g_loss: 0.8301
# Epoch [   75/  100] | d_loss: 1.3491 | g_loss: 0.9685
# Epoch [   75/  100] | d_loss: 1.2882 | g_loss: 0.8429
# Epoch [   75/  100] | d_loss: 1.3546 | g_loss: 0.8591
# Epoch [   75/  100] | d_loss: 1.3396 | g_loss: 0.8091
# Epoch [   75/  100] | d_loss: 1.3038 | g_loss: 0.8823
# Epoch [   75/  100] | d_loss: 1.3053 | g_loss: 0.8714
# Epoch [   75/  100] | d_loss: 1.3168 | g_loss: 0.8330
# Epoch [   76/  100] | d_loss: 1.3412 | g_loss: 0.9235
# Epoch [   76/  100] | d_loss: 1.2772 | g_loss: 1.0217
# Epoch [   76/  100] | d_loss: 1.4131 | g_loss: 0.7993
# Epoch [   76/  100] | d_loss: 1.4403 | g_loss: 0.8271
# Epoch [   76/  100] | d_loss: 1.3394 | g_loss: 0.8525
# Epoch [   76/  100] | d_loss: 1.4072 | g_loss: 0.7912
# Epoch [   76/  100] | d_loss: 1.3447 | g_loss: 0.8613
# Epoch [   76/  100] | d_loss: 1.3344 | g_loss: 1.0241
# Epoch [   76/  100] | d_loss: 1.3165 | g_loss: 0.9496
# Epoch [   76/  100] | d_loss: 1.2479 | g_loss: 1.0337
# Epoch [   77/  100] | d_loss: 1.2792 | g_loss: 1.0188
# Epoch [   77/  100] | d_loss: 1.3125 | g_loss: 0.8942
# Epoch [   77/  100] | d_loss: 1.2227 | g_loss: 1.1571
# Epoch [   77/  100] | d_loss: 1.3164 | g_loss: 0.9774
# Epoch [   77/  100] | d_loss: 1.3323 | g_loss: 0.8774
# Epoch [   77/  100] | d_loss: 1.3287 | g_loss: 0.8775
# Epoch [   77/  100] | d_loss: 1.3178 | g_loss: 1.1233
# Epoch [   77/  100] | d_loss: 1.2516 | g_loss: 1.1031
# Epoch [   77/  100] | d_loss: 1.3955 | g_loss: 0.7605
# Epoch [   77/  100] | d_loss: 1.3776 | g_loss: 0.8003
# Epoch [   78/  100] | d_loss: 1.4501 | g_loss: 0.7842
# Epoch [   78/  100] | d_loss: 1.3137 | g_loss: 1.0534
# Epoch [   78/  100] | d_loss: 1.3856 | g_loss: 0.8792
# Epoch [   78/  100] | d_loss: 1.3569 | g_loss: 1.0395
# Epoch [   78/  100] | d_loss: 1.3170 | g_loss: 1.0160
# Epoch [   78/  100] | d_loss: 1.2783 | g_loss: 0.9430
# Epoch [   78/  100] | d_loss: 1.3475 | g_loss: 0.6991
# Epoch [   78/  100] | d_loss: 1.4715 | g_loss: 0.9938
# Epoch [   78/  100] | d_loss: 1.3748 | g_loss: 0.7098
# Epoch [   78/  100] | d_loss: 1.3355 | g_loss: 0.9500
# Epoch [   79/  100] | d_loss: 1.3680 | g_loss: 1.1366
# Epoch [   79/  100] | d_loss: 1.3225 | g_loss: 0.9425
# Epoch [   79/  100] | d_loss: 1.2967 | g_loss: 0.8632
# Epoch [   79/  100] | d_loss: 1.4115 | g_loss: 0.8223
# Epoch [   79/  100] | d_loss: 1.3702 | g_loss: 0.8589
# Epoch [   79/  100] | d_loss: 1.4153 | g_loss: 0.8516
# Epoch [   79/  100] | d_loss: 1.3015 | g_loss: 0.8646
# Epoch [   79/  100] | d_loss: 1.3231 | g_loss: 0.8914
# Epoch [   79/  100] | d_loss: 1.2526 | g_loss: 1.2107
# Epoch [   79/  100] | d_loss: 1.3551 | g_loss: 1.0180
# Epoch [   80/  100] | d_loss: 1.3600 | g_loss: 0.8796
# Epoch [   80/  100] | d_loss: 1.3348 | g_loss: 0.9272
# Epoch [   80/  100] | d_loss: 1.3086 | g_loss: 0.8762
# Epoch [   80/  100] | d_loss: 1.3192 | g_loss: 0.8690
# Epoch [   80/  100] | d_loss: 1.3197 | g_loss: 0.8949
# Epoch [   80/  100] | d_loss: 1.2724 | g_loss: 0.8674
# Epoch [   80/  100] | d_loss: 1.3377 | g_loss: 0.9014
# Epoch [   80/  100] | d_loss: 1.2923 | g_loss: 0.8632
# Epoch [   80/  100] | d_loss: 1.3578 | g_loss: 0.8779
# Epoch [   80/  100] | d_loss: 1.3463 | g_loss: 0.9024
# Epoch [   81/  100] | d_loss: 1.3454 | g_loss: 0.8554
# Epoch [   81/  100] | d_loss: 1.2903 | g_loss: 1.0090
# Epoch [   81/  100] | d_loss: 1.3622 | g_loss: 0.7875
# Epoch [   81/  100] | d_loss: 1.3111 | g_loss: 0.8938
# Epoch [   81/  100] | d_loss: 1.3796 | g_loss: 1.0149
# Epoch [   81/  100] | d_loss: 1.3285 | g_loss: 0.9847
# Epoch [   81/  100] | d_loss: 1.3606 | g_loss: 0.8001
# Epoch [   81/  100] | d_loss: 1.3500 | g_loss: 0.8546
# Epoch [   81/  100] | d_loss: 1.3685 | g_loss: 0.8241
# Epoch [   81/  100] | d_loss: 1.3562 | g_loss: 0.8336
# Epoch [   82/  100] | d_loss: 1.4513 | g_loss: 0.8942
# Epoch [   82/  100] | d_loss: 1.3163 | g_loss: 0.8687
# Epoch [   82/  100] | d_loss: 1.2980 | g_loss: 0.8437
# Epoch [   82/  100] | d_loss: 1.4115 | g_loss: 0.8498
# Epoch [   82/  100] | d_loss: 1.4102 | g_loss: 0.8697
# Epoch [   82/  100] | d_loss: 1.3338 | g_loss: 0.8965
# Epoch [   82/  100] | d_loss: 1.3230 | g_loss: 0.9172
# Epoch [   82/  100] | d_loss: 1.2697 | g_loss: 1.0600
# Epoch [   82/  100] | d_loss: 1.3811 | g_loss: 0.8586
# Epoch [   82/  100] | d_loss: 1.2861 | g_loss: 1.1454
# Epoch [   83/  100] | d_loss: 1.2356 | g_loss: 1.0754
# Epoch [   83/  100] | d_loss: 1.2760 | g_loss: 1.3896
# Epoch [   83/  100] | d_loss: 1.3334 | g_loss: 0.9982
# Epoch [   83/  100] | d_loss: 1.4819 | g_loss: 0.8555
# Epoch [   83/  100] | d_loss: 1.2878 | g_loss: 0.9959
# Epoch [   83/  100] | d_loss: 1.3797 | g_loss: 0.8389
# Epoch [   83/  100] | d_loss: 1.2963 | g_loss: 0.8030
# Epoch [   83/  100] | d_loss: 1.3710 | g_loss: 0.8476
# Epoch [   83/  100] | d_loss: 1.3821 | g_loss: 0.8545
# Epoch [   83/  100] | d_loss: 1.3596 | g_loss: 0.8500
# Epoch [   84/  100] | d_loss: 1.3351 | g_loss: 0.9427
# Epoch [   84/  100] | d_loss: 1.3522 | g_loss: 0.8750
# Epoch [   84/  100] | d_loss: 1.3370 | g_loss: 0.8810
# Epoch [   84/  100] | d_loss: 1.3719 | g_loss: 0.8466
# Epoch [   84/  100] | d_loss: 1.3588 | g_loss: 0.7906
# Epoch [   84/  100] | d_loss: 1.4917 | g_loss: 0.7997
# Epoch [   84/  100] | d_loss: 1.3088 | g_loss: 0.8532
# Epoch [   84/  100] | d_loss: 1.3828 | g_loss: 0.8894
# Epoch [   84/  100] | d_loss: 1.3431 | g_loss: 0.8580
# Epoch [   84/  100] | d_loss: 1.3023 | g_loss: 0.8830
# Epoch [   85/  100] | d_loss: 1.4014 | g_loss: 0.7860
# Epoch [   85/  100] | d_loss: 1.3167 | g_loss: 0.8589
# Epoch [   85/  100] | d_loss: 1.3315 | g_loss: 0.8601
# Epoch [   85/  100] | d_loss: 1.3726 | g_loss: 0.8717
# Epoch [   85/  100] | d_loss: 1.3605 | g_loss: 0.8351
# Epoch [   85/  100] | d_loss: 1.3604 | g_loss: 0.8886
# Epoch [   85/  100] | d_loss: 1.3063 | g_loss: 0.8887
# Epoch [   85/  100] | d_loss: 1.3653 | g_loss: 0.8211
# Epoch [   85/  100] | d_loss: 1.4449 | g_loss: 0.7952
# Epoch [   85/  100] | d_loss: 1.3435 | g_loss: 0.8039
# Epoch [   86/  100] | d_loss: 1.3754 | g_loss: 1.1120
# Epoch [   86/  100] | d_loss: 1.2695 | g_loss: 0.9438
# Epoch [   86/  100] | d_loss: 1.3173 | g_loss: 0.9004
# Epoch [   86/  100] | d_loss: 1.3182 | g_loss: 0.9447
# Epoch [   86/  100] | d_loss: 1.3055 | g_loss: 0.9329
# Epoch [   86/  100] | d_loss: 1.3511 | g_loss: 0.9919
# Epoch [   86/  100] | d_loss: 1.3887 | g_loss: 0.8195
# Epoch [   86/  100] | d_loss: 1.3521 | g_loss: 0.8745
# Epoch [   86/  100] | d_loss: 1.3596 | g_loss: 0.8868
# Epoch [   86/  100] | d_loss: 1.3960 | g_loss: 1.0326
# Epoch [   87/  100] | d_loss: 1.4741 | g_loss: 0.8327
# Epoch [   87/  100] | d_loss: 1.2878 | g_loss: 0.9311
# Epoch [   87/  100] | d_loss: 1.3976 | g_loss: 0.9142
# Epoch [   87/  100] | d_loss: 1.3311 | g_loss: 0.9090
# Epoch [   87/  100] | d_loss: 1.2787 | g_loss: 0.9740
# Epoch [   87/  100] | d_loss: 1.2721 | g_loss: 0.8181
# Epoch [   87/  100] | d_loss: 1.2876 | g_loss: 0.9584
# Epoch [   87/  100] | d_loss: 1.3078 | g_loss: 0.9097
# Epoch [   87/  100] | d_loss: 1.3198 | g_loss: 0.8608
# Epoch [   87/  100] | d_loss: 1.3119 | g_loss: 0.8984
# Epoch [   88/  100] | d_loss: 1.3450 | g_loss: 0.9968
# Epoch [   88/  100] | d_loss: 1.3038 | g_loss: 0.9931
# Epoch [   88/  100] | d_loss: 1.2229 | g_loss: 1.0303
# Epoch [   88/  100] | d_loss: 1.3226 | g_loss: 0.8846
# Epoch [   88/  100] | d_loss: 1.2724 | g_loss: 0.8694
# Epoch [   88/  100] | d_loss: 1.3568 | g_loss: 0.8217
# Epoch [   88/  100] | d_loss: 1.3051 | g_loss: 1.0747
# Epoch [   88/  100] | d_loss: 1.3262 | g_loss: 1.0166
# Epoch [   88/  100] | d_loss: 1.3122 | g_loss: 0.8422
# Epoch [   88/  100] | d_loss: 1.3934 | g_loss: 1.3113
# Epoch [   89/  100] | d_loss: 1.2998 | g_loss: 0.8499
# Epoch [   89/  100] | d_loss: 1.2984 | g_loss: 0.8704
# Epoch [   89/  100] | d_loss: 1.2487 | g_loss: 0.8572
# Epoch [   89/  100] | d_loss: 1.3227 | g_loss: 0.9377
# Epoch [   89/  100] | d_loss: 1.3719 | g_loss: 0.8900
# Epoch [   89/  100] | d_loss: 1.3571 | g_loss: 0.9017
# Epoch [   89/  100] | d_loss: 1.3295 | g_loss: 0.9125
# Epoch [   89/  100] | d_loss: 1.2840 | g_loss: 0.8802
# Epoch [   89/  100] | d_loss: 1.3578 | g_loss: 0.8549
# Epoch [   89/  100] | d_loss: 1.2805 | g_loss: 0.9411
# Epoch [   90/  100] | d_loss: 1.3666 | g_loss: 0.8427
# Epoch [   90/  100] | d_loss: 1.3543 | g_loss: 0.8756
# Epoch [   90/  100] | d_loss: 1.3207 | g_loss: 0.8886
# Epoch [   90/  100] | d_loss: 1.3336 | g_loss: 0.9765
# Epoch [   90/  100] | d_loss: 1.3082 | g_loss: 0.8695
# Epoch [   90/  100] | d_loss: 1.3044 | g_loss: 0.9705
# Epoch [   90/  100] | d_loss: 1.3933 | g_loss: 0.9714
# Epoch [   90/  100] | d_loss: 1.4475 | g_loss: 0.9270
# Epoch [   90/  100] | d_loss: 1.4163 | g_loss: 1.0292
# Epoch [   90/  100] | d_loss: 1.2982 | g_loss: 0.8642
# Epoch [   91/  100] | d_loss: 1.3369 | g_loss: 0.9326
# Epoch [   91/  100] | d_loss: 1.3215 | g_loss: 0.8544
# Epoch [   91/  100] | d_loss: 1.2989 | g_loss: 0.9169
# Epoch [   91/  100] | d_loss: 1.3839 | g_loss: 0.9865
# Epoch [   91/  100] | d_loss: 1.3657 | g_loss: 0.9398
# Epoch [   91/  100] | d_loss: 1.3450 | g_loss: 1.1601
# Epoch [   91/  100] | d_loss: 1.3299 | g_loss: 0.9834
# Epoch [   91/  100] | d_loss: 1.2701 | g_loss: 0.8950
# Epoch [   91/  100] | d_loss: 1.2873 | g_loss: 1.3155
# Epoch [   91/  100] | d_loss: 1.2531 | g_loss: 1.1162
# Epoch [   92/  100] | d_loss: 1.3068 | g_loss: 0.8985
# Epoch [   92/  100] | d_loss: 1.3176 | g_loss: 0.8851
# Epoch [   92/  100] | d_loss: 1.3531 | g_loss: 0.9141
# Epoch [   92/  100] | d_loss: 1.3458 | g_loss: 0.9132
# Epoch [   92/  100] | d_loss: 1.2934 | g_loss: 0.9315
# Epoch [   92/  100] | d_loss: 1.2939 | g_loss: 0.9741
# Epoch [   92/  100] | d_loss: 1.2894 | g_loss: 0.9851
# Epoch [   92/  100] | d_loss: 1.4317 | g_loss: 0.9759
# Epoch [   92/  100] | d_loss: 1.3130 | g_loss: 0.9887
# Epoch [   92/  100] | d_loss: 1.3285 | g_loss: 0.8982
# Epoch [   93/  100] | d_loss: 1.2642 | g_loss: 0.9920
# Epoch [   93/  100] | d_loss: 1.2968 | g_loss: 0.9165
# Epoch [   93/  100] | d_loss: 1.3710 | g_loss: 0.8799
# Epoch [   93/  100] | d_loss: 1.3657 | g_loss: 0.8716
# Epoch [   93/  100] | d_loss: 1.3216 | g_loss: 0.8368
# Epoch [   93/  100] | d_loss: 1.3373 | g_loss: 0.9088
# Epoch [   93/  100] | d_loss: 1.3525 | g_loss: 0.8460
# Epoch [   93/  100] | d_loss: 1.3630 | g_loss: 0.8048
# Epoch [   93/  100] | d_loss: 1.3883 | g_loss: 0.7898
# Epoch [   93/  100] | d_loss: 1.3842 | g_loss: 0.7899
# Epoch [   94/  100] | d_loss: 1.3650 | g_loss: 0.9343
# Epoch [   94/  100] | d_loss: 1.3462 | g_loss: 0.9131
# Epoch [   94/  100] | d_loss: 1.2956 | g_loss: 0.8222
# Epoch [   94/  100] | d_loss: 1.4173 | g_loss: 0.8536
# Epoch [   94/  100] | d_loss: 1.3970 | g_loss: 0.8077
# Epoch [   94/  100] | d_loss: 1.3486 | g_loss: 1.0102
# Epoch [   94/  100] | d_loss: 1.3545 | g_loss: 0.7876
# Epoch [   94/  100] | d_loss: 1.3671 | g_loss: 0.9894
# Epoch [   94/  100] | d_loss: 1.3650 | g_loss: 0.7979
# Epoch [   94/  100] | d_loss: 1.3642 | g_loss: 0.7785
# Epoch [   95/  100] | d_loss: 1.3491 | g_loss: 1.0672
# Epoch [   95/  100] | d_loss: 1.3702 | g_loss: 0.8048
# Epoch [   95/  100] | d_loss: 1.3011 | g_loss: 0.8306
# Epoch [   95/  100] | d_loss: 1.4093 | g_loss: 0.8309
# Epoch [   95/  100] | d_loss: 1.3273 | g_loss: 0.9054
# Epoch [   95/  100] | d_loss: 1.3549 | g_loss: 0.9038
# Epoch [   95/  100] | d_loss: 1.3249 | g_loss: 0.8526
# Epoch [   95/  100] | d_loss: 1.3381 | g_loss: 0.8890
# Epoch [   95/  100] | d_loss: 1.3809 | g_loss: 0.8163
# Epoch [   95/  100] | d_loss: 1.3788 | g_loss: 0.8821
# Epoch [   96/  100] | d_loss: 1.2975 | g_loss: 0.8573
# Epoch [   96/  100] | d_loss: 1.3355 | g_loss: 0.8364
# Epoch [   96/  100] | d_loss: 1.3171 | g_loss: 0.7947
# Epoch [   96/  100] | d_loss: 1.3769 | g_loss: 0.8755
# Epoch [   96/  100] | d_loss: 1.3237 | g_loss: 0.8641
# Epoch [   96/  100] | d_loss: 1.3630 | g_loss: 0.9344
# Epoch [   96/  100] | d_loss: 1.3032 | g_loss: 1.1395
# Epoch [   96/  100] | d_loss: 1.2749 | g_loss: 1.1984
# Epoch [   96/  100] | d_loss: 1.4302 | g_loss: 0.8231
# Epoch [   96/  100] | d_loss: 1.3010 | g_loss: 0.9539
# Epoch [   97/  100] | d_loss: 1.2914 | g_loss: 1.0148
# Epoch [   97/  100] | d_loss: 1.2877 | g_loss: 0.8819
# Epoch [   97/  100] | d_loss: 1.3038 | g_loss: 0.8669
# Epoch [   97/  100] | d_loss: 1.2940 | g_loss: 1.0213
# Epoch [   97/  100] | d_loss: 1.2816 | g_loss: 0.9730
# Epoch [   97/  100] | d_loss: 1.3132 | g_loss: 0.8829
# Epoch [   97/  100] | d_loss: 1.2871 | g_loss: 0.8552
# Epoch [   97/  100] | d_loss: 1.3492 | g_loss: 0.8469
# Epoch [   97/  100] | d_loss: 1.3408 | g_loss: 0.8730
# Epoch [   97/  100] | d_loss: 1.3621 | g_loss: 0.8600
# Epoch [   98/  100] | d_loss: 1.3724 | g_loss: 0.8657
# Epoch [   98/  100] | d_loss: 1.3519 | g_loss: 0.8896
# Epoch [   98/  100] | d_loss: 1.3188 | g_loss: 0.8636
# Epoch [   98/  100] | d_loss: 1.3481 | g_loss: 0.9320
# Epoch [   98/  100] | d_loss: 1.3112 | g_loss: 1.1220
# Epoch [   98/  100] | d_loss: 1.3673 | g_loss: 0.8827
# Epoch [   98/  100] | d_loss: 1.3547 | g_loss: 0.8680
# Epoch [   98/  100] | d_loss: 1.3898 | g_loss: 0.8869
# Epoch [   98/  100] | d_loss: 1.3511 | g_loss: 0.9139
# Epoch [   98/  100] | d_loss: 1.3465 | g_loss: 0.9579
# Epoch [   99/  100] | d_loss: 1.3076 | g_loss: 0.8053
# Epoch [   99/  100] | d_loss: 1.3070 | g_loss: 0.8141
# Epoch [   99/  100] | d_loss: 1.2874 | g_loss: 0.8309
# Epoch [   99/  100] | d_loss: 1.3238 | g_loss: 0.8596
# Epoch [   99/  100] | d_loss: 1.2727 | g_loss: 0.8662
# Epoch [   99/  100] | d_loss: 1.3430 | g_loss: 0.8893
# Epoch [   99/  100] | d_loss: 1.3037 | g_loss: 0.8118
# Epoch [   99/  100] | d_loss: 1.2812 | g_loss: 0.9158
# Epoch [   99/  100] | d_loss: 1.3236 | g_loss: 0.9557
# Epoch [   99/  100] | d_loss: 1.2924 | g_loss: 0.8884
# Epoch [  100/  100] | d_loss: 1.3250 | g_loss: 0.8876
# Epoch [  100/  100] | d_loss: 1.3325 | g_loss: 0.7868
# Epoch [  100/  100] | d_loss: 1.3701 | g_loss: 0.8983
# Epoch [  100/  100] | d_loss: 1.3625 | g_loss: 0.7647
# Epoch [  100/  100] | d_loss: 1.3269 | g_loss: 0.9479
# Epoch [  100/  100] | d_loss: 1.3498 | g_loss: 0.8118
# Epoch [  100/  100] | d_loss: 1.3359 | g_loss: 0.7912
# Epoch [  100/  100] | d_loss: 1.2930 | g_loss: 1.0170
# Epoch [  100/  100] | d_loss: 1.3904 | g_loss: 0.9479
# Epoch [  100/  100] | d_loss: 1.3143 | g_loss: 0.7795

# %%
# helper function for viewing a list of passed in sample images
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(7,7), nrows=4, ncols=4, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach()
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((28,28)), cmap='Greys_r')

# %%
# Load samples from generator, taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %%
# -1 indicates final epoch's samples (the last in the list)
view_samples(-1, samples)

# %%
rows = 10 # split epochs into 10, so 100/10 = every 10 epochs
cols = 6
fig, axes = plt.subplots(figsize=(7,12), nrows=rows, ncols=cols, sharex=True, sharey=True)

for sample, ax_row in zip(samples[::int(len(samples)/rows)], axes):
    for img, ax in zip(sample[::int(len(sample)/cols)], ax_row):
        img = img.detach()
        ax.imshow(img.reshape((28,28)), cmap='Greys_r',interpolation='nearest')
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)

# %%
# randomly generated, new latent vectors
sample_size=16
rand_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
rand_z = torch.from_numpy(rand_z).float()

G.eval() # eval mode
# generated samples
rand_images = G(rand_z)

# 0 indicates the first set of samples in the passed in list
# and we only have one batch of samples, here
view_samples(0, [rand_images])
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1614: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
